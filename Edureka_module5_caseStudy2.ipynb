# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
os.chdir('C:\\Users\\Manoj\\Desktop\\Edureka_Python')

# %%
data= pd.read_csv("Salaries.csv")
data.head()
# Out:
# C:\Users\Manoj\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# ...

# %%
len(data)
# Out:
# 148648

# %%
data[data['Year']==2014].loc[:,['JobTitle','TotalPay']].groupby('JobTitle').mean().sort_values(['TotalPay'], ascending = False).head(1)
# Out:
#                           TotalPay
# JobTitle
# Chief Investment Officer  339653.7

# %% [markdown]
# How much money could have been saved in Year 2014 by stopping
# OverTimePay?

# %%
data.loc[:,['Year','OvertimePay']].groupby('Year').sum()
#1359744789
# Out:
#        OvertimePay
# Year
# 2011  1.638191e+08
# 2012  1.846650e+08
# 2013  1.986214e+08
# 2014  2.059186e+08

# %%
data.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# ...

# %%
data[(data['Year']==2014) & (data['Agency']=='San Francisco')].loc[:,['Year','JobTitle','TotalPayBenefits']].groupby('JobTitle')['TotalPayBenefits'].nlargest(5)
# Out:
# JobTitle
# ACPO,JuvP, Juv Prob (SFERS)     135281     80266.37
# ASR Senior Office Specialist    117356    161738.89
#                                 128834    103718.95
#                                 128920    103404.52
#                                 128957    103299.75
#                                 129227    102328.61
# ASR-Office Assistant            134554     83097.49
#                                 134558     83097.46
#                                 134744     82337.11
#                                 135499     79179.11
#                                 135520     79043.96
# Account Clerk                   134119     84755.64
#                                 134153     84583.47
#                                 134193     84430.20
#                                 134227     84264.86
#                                 134250     84166.33
# Accountant I                    129819    100245.90
#                                 140728     28110.76
# ...

# %%
data.loc[:,['EmployeeName','Year','TotalPayBenefits']].nlargest(5,'TotalPayBenefits')
# Out:
#                 EmployeeName  Year  TotalPayBenefits
# 0             NATHANIEL FORD  2011         567595.43
# 1               GARY JIMENEZ  2011         538909.28
# 110529           David Shinn  2014         510732.68
# 110530            Amy P Hart  2014         479652.21
# 110531  William J Coaker Jr.  2014         436224.36

# %%
data[(data['Year']==2014) & (data['Agency']=='San Francisco')]
# Out:
#             Id            EmployeeName                        JobTitle  \
# 110529  110532             David Shinn                  Deputy Chief 3
# 110530  110533              Amy P Hart               Asst Med Examiner
# 110531  110534    William J Coaker Jr.        Chief Investment Officer
# 110532  110535          Gregory P Suhr                 Chief of Police
# 110533  110536    Joanne M Hayes-White          Chief, Fire Department
# 110534  110537         Ellen G Moffatt               Asst Med Examiner
# 110535  110538           John L Martin                     Dept Head V
# 110536  110539       Harlan L Kelly-Jr     Executive Contract Employee
# 110537  110540              Samson Lai  Battalion Chief, Fire Suppress
# 110538  110541        David L Franklin    Asst Chf of Dept (Fire Dept)
# 110539  110542        Edward D Reiskin      Gen Mgr, Public Trnsp Dept
# 110540  110543             Yifang Qian     Senior Physician Specialist
# ...

# %%
data[(data['Year']==2014) & (data['Agency']=='San Francisco')].loc[:,['Year','JobTitle','TotalPayBenefits']].groupby('JobTitle')['TotalPayBenefits'].nsmallest(5)
# Out:
# JobTitle
# ACPO,JuvP, Juv Prob (SFERS)     135281     80266.37
# ASR Senior Office Specialist    142047     18843.77
#                                 140763     27761.48
#                                 140468     30611.66
#                                 137006     67640.27
#                                 136347     73789.85
# ASR-Office Assistant            140719     28224.91
#                                 140185     33440.68
#                                 138659     49177.03
#                                 138402     52498.99
#                                 137177     66015.76
# Account Clerk                   148624         0.00
#                                 148376       280.46
#                                 147617      1461.28
#                                 145626      5377.28
#                                 145384      6133.18
# Accountant I                    140728     28110.76
#                                 129819    100245.90
# ...

# %%
x =data[data['Year']==2014].iloc[:,4]
totalOT = sum(x)
y = data[data['Year']==2014].iloc[:,7]
totalPAY= sum(y)
print(totalOT)
print(totalPAY)
percent = totalOT/totalPAY *100
print(percent)
# Out:
# 205918599.27000067
# 2876910951.2599883
# 7.157628538339547

# %%
data[data['Year']==2014].groupby('JobTitle').mean().sort_values(['TotalPay'], ascending= True).head(5)
# Out:
#                                        Id      BasePay  OvertimePay  \
# JobTitle
# Special Assistant 15        145529.000000     0.000000     0.000000
# BdComm Mbr, Grp2,M=$25/Mtg  148342.800000   325.000000     0.000000
# BdComm Mbr, Grp3,M=$50/Mtg  147963.666667   691.904762     0.000000
# Special Examiner            147736.034483  1124.488276     6.416897
# BdComm Mbr, Grp5,M$100/Mo   147709.092593  1300.115926     0.000000
#
#                              OtherPay     Benefits     TotalPay  \
# JobTitle
# Special Assistant 15         0.000000  5650.860000     0.000000
# BdComm Mbr, Grp2,M=$25/Mtg   0.000000    20.417556   325.000000
# BdComm Mbr, Grp3,M=$50/Mtg   0.000000   260.913333   691.904762
# Special Examiner            10.267241   201.578276  1141.172414
# BdComm Mbr, Grp5,M$100/Mo    0.000000    35.300185  1300.115926
#
#                             TotalPayBenefits    Year  Notes
# JobTitle
# Special Assistant 15             5650.860000  2014.0    NaN
# ...
