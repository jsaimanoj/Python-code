# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
os.chdir('C:\\Users\\Manoj\\Desktop\\Edureka_Python')

# %%
hurr = pd.read_csv("Hurricanes.csv")

# %%
hurr.head()
# Out:
#    Year  Hurricanes
# 0  1914           0
# 1  1915           5
# 2  1916          10
# 3  1917           2
# 4  1918           4

# %%
a4_dims = (16, 8)
fig, ax = plt.subplots(figsize=a4_dims)
sns.barplot(x= 'Year', y = 'Hurricanes', data = hurr,ax=ax)
sns.set_context("paper")

# %%
temp = pd.read_csv("CityTemps.csv")
temp.head()
# Out:
#    Year  Month  Moscow  Melbourne  San Francisco
# 0  2014      1    -8.6       22.0           12.8
# 1  2014      2    -1.9       21.5           12.7
# 2  2014      3     2.8       19.5           15.0
# 3  2014      4     7.0       15.8           15.7
# 4  2014      5    16.0       13.9           17.5

# %%
plt.subplot(1,2,1)
sns.distplot(temp['San Francisco'], kde= False)
plt.show()
plt.subplot(1,2,2)
sns.distplot(temp['Moscow'], kde= False)
plt.show()

# %%
dt = pd.read_table("data_file.txt", delimiter = ",")
dt.head()
# Out:
#    account_number                           name item_code category  quantity  \
# 0          296809                    Carroll PLC  QN-82852     Belt        13
# 1           98022              Heidenreich-Bosco  MJ-21460    Shoes        19
# 2          563905  Kerluke, Reilly and Bechtelar  AS-93055    Shirt        12
# 3           93356                  Waters-Walker  AS-93055    Shirt         5
# 4          659366                  Waelchi-Fahey  AS-93055    Shirt        18
#
#    unit price  net_price                 date
# 0       44.48     578.24  2014-09-27 07:13:03
# 1       53.62    1018.78  2014-07-29 02:10:44
# 2       24.16     289.92  2014-03-01 10:51:24
# 3       82.68     413.40  2013-11-17 20:41:11
# 4       99.64    1793.52  2014-01-03 08:14:27

# %%
dt.to_csv("DataFile.csv")

# %%
X = [1,2,3,4]
y = [20, 21, 20.5, 20.8]

# %%
plt.plot(X,y)

# %%
help(plt.plot)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, scalex=True, scaley=True, data=None, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
plt.plot(X,y, marker= "+", linestyle = "dotted")
plt.plot(y_error,color = "red")
plt.title("X over Y")
plt.xlabel("its X")
plt.ylabel("its Y")
# Out:
# Text(0, 0.5, 'its Y')

# %%
y_error = [0.12, 0.13, 0.2, 0.1]

# %%
dataset = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
'female': [0, 1, 1, 0, 1],
'age': [42, 52, 36, 24, 73],
'preTestScore': [4, 24, 31, 2, 3],
'postTestScore': [25, 94, 57, 62, 70]}

# %%
dataset
# Out:
# {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
#  'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
#  'female': [0, 1, 1, 0, 1],
#  'age': [42, 52, 36, 24, 73],
#  'preTestScore': [4, 24, 31, 2, 3],
#  'postTestScore': [25, 94, 57, 62, 70]}

# %%
dataset = pd.DataFrame(dataset)

# %%
dataset
# Out:
#   first_name last_name  female  age  preTestScore  postTestScore
# 0      Jason    Miller       0   42             4             25
# 1      Molly  Jacobson       1   52            24             94
# 2       Tina       Ali       1   36            31             57
# 3       Jake    Milner       0   24             2             62
# 4        Amy     Cooze       1   73             3             70

# %%
plt.scatter(x=dataset['preTestScore'], y =dataset['preTestScore'], s = dataset['age'])
plt.show()

# %%
help(plt.scatter)
# Out:
# Help on function scatter in module matplotlib.pyplot:
#
# scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, verts=None, edgecolors=None, *, data=None, **kwargs)
#     A scatter plot of *y* vs *x* with varying marker size and/or color.
#
#     Parameters
#     ----------
#     x, y : array_like, shape (n, )
#         The data positions.
#
#     s : scalar or array_like, shape (n, ), optional
#         The marker size in points**2.
#         Default is ``rcParams['lines.markersize'] ** 2``.
#
#     c : color, sequence, or sequence of color, optional
#         The marker color. Possible values:
#
#         - A single color format string.
#         - A sequence of color specifications of length n.
#         - A sequence of n numbers to be mapped to colors using *cmap* and
#           *norm*.
#         - A 2-D array in which the rows are RGB or RGBA.
#
# ...

# %%
plt.scatter(x=dataset['preTestScore'], y =dataset['preTestScore'], s = 300, c = dataset['female'])
plt.show()
