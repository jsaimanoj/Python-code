# %%
import pandas as pd
import numpy as np
import math

# %% [markdown]
# A robot moves in a plane starting from the original point (0,0).
# The robot can move toward UP, DOWN, LEFT and RIGHT with a given steps. The trace of robot movement is shown as the following:
# UP 5
# DOWN 3
# LEFT 3
# RIGHT 2
# The numbers after the direction are steps. Please write a program to compute the distance from current
# position after a sequence of movement and original point. If the distance is a float, then just print the nearest integer.

# %%
pos=[0,0]
moves={"UP":[0,1],
       "DOWN":[0,-1],
       "LEFT":[-1,0],
       "RIGHT":[1,0]}

#Set inputs
data=["UP 5",
    "DOWN 3",
    "LEFT 3",
    "RIGHT 2"]

#Move robot on valid moves
for inp in data:
    parts=inp.split()    
    mv=parts[0]
    val=parts[1]
    if mv in moves and val.isnumeric():
        pos[0] += moves[mv][0]*int(val)
        pos[1] += moves[mv][1]*int(val)

#get distance     
distance=math.sqrt(pos[0]**2 + pos[1]**2)
print(distance, "from [0,0] to",pos)
# Out:
# 2.23606797749979 from [0,0] to [-1, 2]

# %% [markdown]
# #Weather forecasting organization wants to show is it day or night. So, write a
# program for such organization to find whether is it dark outside or not.

# %%
import time
mytime = time.localtime()
if mytime.tm_hour < 6 or mytime.tm_hour > 18:
    print ('It is night-time')
else:
    print ('It is day-time')
# Out:
# It is night-time

# %% [markdown]
# #Write a program to find distance between two locations when their latitude and
# longitudes are given.

# %%
from math import sin, cos, sqrt, atan2, radians

# approximate radius of earth in km
R = 6373.0

lat1 = radians(52.2296756)
lon1 = radians(21.0122287)
lat2 = radians(52.406374)
lon2 = radians(16.9251681)

dlon = lon2 - lon1
dlat = lat2 - lat1

a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
c = 2 * atan2(sqrt(a), sqrt(1 - a))

distance = R * c

print("Result:", distance)
print("Should be:", 278.546, "km")
# Out:
# Result: 278.54558935106695
# Should be: 278.546 km

# %% [markdown]
# #Design a software for bank system. There should be options like cash withdraw,
# cash credit and change password. According to user input, the software should
# provide required output.

# %%
def CashWithdrawal():
    PIN=input('Enter ATM or CARD PIN to proceed:')
    if PIN=='123':
        print ('***Thank You For Banking With Us***')
    else:
        print ('You Have Enterd Invalid PIN. Try Again')

def CashCredit():
    PIN=input('Enter ATM or CARD PIN to proceed:')
    if PIN=='123':
        AMT=input('Enter Amount That You Wish to Credit To Bank:')
        print ('***Thank You For Banking With Us***')
    else:
        print ('You Have Enterd Invalid PIN. Try Again')

def ChangePassword():
    PIN=input('Enter ATM or CARD PIN to proceed:')
    if PIN=='123':
        OLD_PWD=raw_input('Please Enter Your Old Password:')
        print ('***Thank You For Banking With Us***')
    else:
        print ('You Have Enterd Invalid PIN. Try Again')

def Main():
    print ('Welcome to XYZ Bank\nChoose from below options')
    print ('1. Case withdrawal\n2. Cash credit\n3. Change password')
    opt=input('Enter your option:')
    if opt=='1':
        CashWithdrawal()
    if opt=='2':
        CashCredit()
    if opt=='3':
        ChangePassword()

Main()
# Out:
# Welcome to XYZ Bank
# Choose from below options
# 1. Case withdrawal
# 2. Cash credit
# 3. Change password
# Enter your option:1
# Enter ATM or CARD PIN to proceed:123
# ***Thank You For Banking With Us***

# %% [markdown]
# #Write a program which will find all such numbers which are divisible by 7 but are
# not a multiple of 5, between 2000 and 3200 (both included). The numbers obtained
# should be printed in a comma-separated sequence on a single line.

# %%
liste = []
for i in range(2000,3201):
    if (i%7==0) and (i%5!=0):
        liste.append(i)
    else:
        pass
print(liste)
# Out:
# [2002, 2009, 2016, 2023, 2037, 2044, 2051, 2058, 2072, 2079, 2086, 2093, 2107, 2114, 2121, 2128, 2142, 2149, 2156, 2163, 2177, 2184, 2191, 2198, 2212, 2219, 2226, 2233, 2247, 2254, 2261, 2268, 2282, 2289, 2296, 2303, 2317, 2324, 2331, 2338, 2352, 2359, 2366, 2373, 2387, 2394, 2401, 2408, 2422, 2429, 2436, 2443, 2457, 2464, 2471, 2478, 2492, 2499, 2506, 2513, 2527, 2534, 2541, 2548, 2562, 2569, 2576, 2583, 2597, 2604, 2611, 2618, 2632, 2639, 2646, 2653, 2667, 2674, 2681, 2688, 2702, 2709, 2716, 2723, 2737, 2744, 2751, 2758, 2772, 2779, 2786, 2793, 2807, 2814, 2821, 2828, 2842, 2849, 2856, 2863, 2877, 2884, 2891, 2898, 2912, 2919, 2926, 2933, 2947, 2954, 2961, 2968, 2982, 2989, 2996, 3003, 3017, 3024, 3031, 3038, 3052, 3059, 3066, 3073, 3087, 3094, 3101, 3108, 3122, 3129, 3136, 3143, 3157, 3164, 3171, 3178, 3192, 3199]

# %% [markdown]
# #Write a program which can compute the factorial of a given numbers. Use recursion
# to find it.

# %%
def recur_factorial(n):  
   if n == 1:  
       return n  
   else:  
       return n*recur_factorial(n-1)  
# take input from the user  
num = int(input("Enter a number: "))  
# check is the number is negative  
if num < 0:  
   print("Sorry, factorial does not exist for negative numbers")  
elif num == 0:  
   print("The factorial of 0 is 1")  
else:  
   print("The factorial of",num,"is",recur_factorial(num))
# Out:
# Enter a number: 8
# The factorial of 8 is 40320

# %% [markdown]
# Write a program that calculates and prints the value according to the given formula:
# Q = Square root of [(2 * C * D)/H]
# Following are the fixed values of C and H: C is 50. H is 30.
# D is the variable whose values should be input to your program in a commaseparated
# sequence.

# %%
c=50
h=30
value = []
items=[x for x in input().split(',')]
for d in items:
    value.append(str(int(round(math.sqrt(2*c*float(d)/h)))))

print (value)
# Out:
# 10
# ['6']

# %% [markdown]
# Write a program which takes 2 digits, X,Y as input and generates a 2-dimensional
# array. The element value in the i-th row and j-th column of the array should be i*j.
# Note: i=0,1.., X-1; j=0,1,¡Y-

# %%
row_num = int(input("Input number of rows: "))
col_num = int(input("Input number of columns: "))
multi_list = [[0 for col in range(col_num)] for row in range(row_num)]

for row in range(row_num):
    for col in range(col_num):
        multi_list[row][col]= row*col

print(multi_list)
# Out:
# Input number of rows: 3
# Input number of columns: 4
# [[0, 0, 0, 0], [0, 1, 2, 3], [0, 2, 4, 6]]

# %% [markdown]
# #Write a program that accepts a comma separated sequence of words as input and
# prints the words in a comma-separated sequence after sorting them alphabetically.

# %%
my_words = input("enter the words:")
words = [word for word in my_words.split(",")]
print(",".join(sorted(list(set(words)))))
# Out:
# enter the words:jack,john,alpha,beta,zeta
# alpha,beta,jack,john,zeta

# %% [markdown]
# Write a program that accepts sequence of lines as input and prints the lines after
# making all characters in the sentence capitalized.

# %%
lines = []
while True:
    l = input()
    if l:
        lines.append(l.upper())
    else:
        break

for l in lines:
    print(l)
# Out:
# hi
# how
# are
# you
#
# HI
# HOW
# ARE
# YOU

# %% [markdown]
# Write a program that accepts a sequence of whitespace separated words as input
# and prints the words after removing all duplicate words and sorting them
# alphanumerically.

# %%
words = input("Enter sequence of words separated by whitespace: ").split(' ')
words_set = set(words)
print (' '.join(sorted(words_set)))
print (words_set)
# Out:
# Enter sequence of words separated by whitespace: hello world and practice makes perfect and hello world again
# again and hello makes perfect practice world
# {'makes', 'and', 'again', 'perfect', 'world', 'hello', 'practice'}

# %% [markdown]
# Write a program which accepts a sequence of comma separated 4 digit binary
# numbers as its input and then check whether they are divisible by 5 or not. The
# numbers that are divisible by 5 are to be printed in a comma separated sequence.

# %%
items = []
num = [x for x in input().split(',')]
for p in num:
    x = int(p, 2)
    if not x%5:
        items.append(p)
print(','.join(items))
# Out:
# 1101,1010,0101
# 1010,0101

# %% [markdown]
# Write a program that accepts a sentence and calculate the number of upper case
# letters and lower case letters.

# %%
my_sentence = input("Enter the sentence:")
d={"UPPER_CASE":0, "LOWER_CASE":0}
for c in my_sentence:
        if c.isupper():
           d["UPPER_CASE"]+=1
        elif c.islower():
           d["LOWER_CASE"]+=1
        else:
            pass
print(d)
# Out:
# Enter the sentence:How DID you Do that
# {'UPPER_CASE': 5, 'LOWER_CASE': 10}

# %% [markdown]
# Give example of fsum and sum function of math library.

# %%
import math

# %%
math.fsum(range(10))
# Out:
# 45.0

# %%
sum(range(10))
# Out:
# 45

# %%
import os
import pandas as pd
import numpy as np

# %%
os.chdir("C:\\Users\\Manoj\\Desktop\\Edureka_Python")
os.getcwd()
# Out:
# 'C:\\Users\\Manoj\\Desktop\\Edureka_Python'

# %%
bank_data = pd.read_csv("bank-data.csv")

# %%
bank_data.head()
# Out:
#    age          job  marital    y
# 0   20      student   single  yes
# 1   32   management   single  yes
# 2   49   technician  married  yes
# 3   32  blue-collar  married  yes
# 4   33   management  married  yes

# %%
jobs=list(set(bank_data.iloc[:,1].values))
jobs
# Out:
# ['services',
#  'blue-collar',
#  'admin.',
#  'self-employed',
#  'entrepreneur',
#  'technician',
#  'housemaid',
#  'student',
#  'management']

# %%
minAge=min(bank_data.age)
maxAge=max(bank_data.age)

age_criteria = {"minAge":19,"maxAge" :80}
type(age_criteria)
# Out:
# dict

# %%
while True:
    profession = str.casefold(input("Enter your profession:"))
    age = int(input("Enter your age:"))
    
    if profession in jobs and age in range(minAge,maxAge):
        print("You are Eligible for the loan.")
    elif profession == 'END':
        break
# Out:
# Enter your profession:end
# Enter your age:20
# Enter your profession:
# Enter your age:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-a44ce19bc3db> in <module>
#       1 while True:
#       2     profession = str.casefold(input("Enter your profession:"))
# ----> 3     age = int(input("Enter your age:"))
#       4
#       5     if profession in jobs and age in range(minAge,maxAge):
#
# ValueError: invalid literal for int() with base 10: ''

# %%
cust = pd.read_csv("FairDealCustomerData.csv")
cust
# Out:
#                  Name                      FullName  Score
# 0              Braund              Mr. Owen Harris       1
# 1           Heikkinen                  Miss. Laina       0
# 2               Allen            Mr. William Henry       0
# 3               Moran                    Mr. James       0
# 4            McCarthy                Mr. Timothy J       0
# 5             Bonnell              Miss. Elizabeth       0
# 6           Andersson             Mr. Anders Johan       0
# 7            Williams           Mr. Charles Eugene       1
# 8          Masselmani                  Mrs. Fatima       0
# 9              Fynney                 Mr. Joseph J       0
# 10            Beesley                 Mr. Lawrence       0
# 11             Sloper         Mr. William Thompson       0
# 12               Emir            Mr. Farred Chehab       0
# 13           Todoroff                    Mr. Lalio       0
# 14          Uruchurtu                Don. Manuel E       1
# 15              Glynn            Miss. Mary Agatha       0
# 16            Wheadon                 Mr. Edward H       0
# 17              Meyer             Mr. Edgar Joseph       0
# 18          Holverson          Mr. Alexander Oskar       0
# 19              Mamee                    Mr. Hanna       0
# 20             Kraeff                  Mr. Theodor       0
# 21             Rogers             Mr. William John       1
# 22             Lennon                    Mr. Denis       0
# 23             Samaan                  Mr. Youssef       0
# 24              Ostby      Mr. Engelhart Cornelius       0
# 25            Woolner                     Mr. Hugh       0
# 26              Novel                 Mr. Mansouer       0
# 27         Sirayanian                    Mr. Orsen       0
# 28              Icard                 Miss. Amelie       1
# 29             Harris          Mr. Henry Birkhardt       0
# ..                ...                           ...    ...
# 502        Augustsson                   Mr. Albert       0
# 503           Compton           Miss. Sara Rebecca       0
# 504            Sirota                  Mr. Maurice       1
# 505              Chip                    Mr. Chang       0
# 506          Marechal                   Mr. Pierre       0
# 507          Serepeca                Miss. Augusta       0
# 508     Lemberopolous                  Mr. Peter L       0
# 509            Abbing                  Mr. Anthony       0
# 510              Sage           Mr. Douglas Bullen       0
# 511           Markoff                    Mr. Marin       1
# 512            Harper                    Rev. John       0
# 513          Svensson                    Mr. Johan       0
# 514              Daly             Mr. Peter Denis        0
# 515              Razi                   Mr. Raihed       0
# 516            Hansen              Mr. Claus Peter       0
# 517              Gill             Mr. John William       0
# 518      Duran y More               Miss. Asuncion       1
# 519          Roebling   Mr. Washington Augustus II       0
# 520     van Melkebeke                 Mr. Philemon       0
# 521            Balkic                    Mr. Cerin       0
# 522          Carlsson               Mr. Frans Olof       0
# 523   Vander Cruyssen                   Mr. Victor       0
# 524            Laleff                   Mr. Kristo       0
# 525            Markun                   Mr. Johann       1
# 526          Dahlberg           Miss. Gerda Ulrika       0
# 527          Banfield          Mr. Frederick James       0
# 528          Sutehall                 Mr. Henry Jr       0
# 529          Montvila                  Rev. Juozas       0
# 530              Behr              Mr. Karl Howell       0
# 531            Dooley                  Mr. Patrick       0
#
# [532 rows x 3 columns]

# %%
from re import split

# %%
names = list(cust.FullName)
names
# Out:
# [' Mr. Owen Harris ',
#  ' Miss. Laina ',
#  ' Mr. William Henry ',
#  ' Mr. James ',
#  ' Mr. Timothy J ',
#  ' Miss. Elizabeth ',
#  ' Mr. Anders Johan ',
#  ' Mr. Charles Eugene ',
#  ' Mrs. Fatima ',
#  ' Mr. Joseph J ',
#  ' Mr. Lawrence ',
#  ' Mr. William Thompson ',
#  ' Mr. Farred Chehab ',
#  ' Mr. Lalio ',
#  ' Don. Manuel E ',
#  ' Miss. Mary Agatha ',
#  ' Mr. Edward H ',
#  ' Mr. Edgar Joseph ',
#  ' Mr. Alexander Oskar ',
#  ' Mr. Hanna ',
#  ' Mr. Theodor ',
#  ' Mr. William John ',
#  ' Mr. Denis ',
#  ' Mr. Youssef ',
#  ' Mr. Engelhart Cornelius ',
#  ' Mr. Hugh ',
#  ' Mr. Mansouer ',
#  ' Mr. Orsen ',
#  ' Miss. Amelie ',
#  ' Mr. Henry Birkhardt ',
#  ' Mr. Albert A ',
#  ' Master. Gerios ',
#  ' Mr. Vincenz ',
#  ' Mr. Stephen Curnow ',
#  ' Mr. Apostolos ',
#  ' Mr. Lee ',
#  ' Mr. Sigurd Hansen ',
#  ' Mr. Ivan ',
#  ' Mr. Rahamin Haim ',
#  ' Miss. Elizabeth ',
#  ' Mr. Achille ',
#  ' Mr. Jan Baptist ',
#  ' Miss. Brigdet Delia ',
#  ' Mr. Francisco M ',
#  ' Mr. Selman Francis ',
#  ' Miss. Mabel Helen ',
#  ' Mr. Francesco ',
#  ' Mr. Emil ',
#  ' Mr. Herbert Fuller ',
#  ' Mr. Bertram Frank ',
#  ' Mr. Daniel ',
#  ' Mr. Charles Joseph ',
#  ' Mr. George B ',
#  ' Mr. William Bertram ',
#  ' Mr. Sinai ',
#  ' Miss. Matilda ',
#  ' Mr. Gustaf Joel ',
#  ' Mr. Anders Vilhelm ',
#  ' Mr. Stoytcho ',
#  ' Mr. Albert Johan ',
#  ' Mr. Tido ',
#  ' Miss. Bertha ',
#  ' Mr. Walter Chamberlain ',
#  ' Mr. David John ',
#  ' Mr. Patrick ',
#  ' Mr. William John Robert ',
#  ' Mr. Quigg Edmond ',
#  ' Mr. Leonard Charles ',
#  ' Mr. Nicholas ',
#  ' Miss. Susan ',
#  ' Mr. Percival Wayland ',
#  ' Mr. Martin ',
#  ' Mr. Fridtjof Arne ',
#  ' Miss. Anna ',
#  ' Mr. Johan ',
#  ' Mr. Jozef ',
#  ' Mr. Samuel James Hayden ',
#  ' Mr. Emile ',
#  ' Mr. Jacques Heath ',
#  ' Mr. Victor ',
#  ' Miss. Anna Sofia ',
#  ' Rev. Thomas Roussel Davids ',
#  ' Rev. Robert James ',
#  ' Mr. Alfonzo ',
#  ' Mr. Austin Blyler ',
#  ' Mr. Tyrell William ',
#  ' Mr. Neal ',
#  ' Mr. Juho ',
#  ' Capt. Edward Gifford ',
#  ' Miss. Anna ',
#  ' Mr. Michael ',
#  ' Mr. Johannes Joseph ',
#  ' Mr. Lalio ',
#  ' Mr. August Sigfrid ',
#  ' Mr. Thomas Leonard ',
#  ' Mr. John ',
#  ' Mr. Iisakki Antino Aijo ',
#  ' Dr. Arthur Jackson ',
#  ' Miss. Mary ',
#  ' Mr. Daniel J ',
#  ' Mr. Daniel Danielsen ',
#  ' Mr. Rene Aime ',
#  ' Mr. Niels Peder ',
#  ' Mr. Dibo ',
#  ' Mr. Roger ',
#  ' Mr. Thomas J ',
#  ' Mr. Milton Clyde ',
#  ' Mr. Andrew G ',
#  ' Mr. William ',
#  ' Mr. Benjamin ',
#  ' Miss. Stella Anna ',
#  ' Mr. William Fisher ',
#  ' Mr. Ristiu ',
#  ' Mr. Richard ',
#  ' Mrs. Mara ',
#  ' Mr. Yousseff ',
#  ' Mr. Martin ',
#  ' Mr. Oskar Arvid ',
#  ' Mr. Karl Johan ',
#  ' Mr. Thomas Jr ',
#  ' Mr. August ',
#  ' Mr. William ',
#  ' Mr. James ',
#  ' Mr. Richard James ',
#  ' Mr. Ernest Portage ',
#  ' Mr. Richard ',
#  ' Miss. Wendla Maria ',
#  ' Mr. Albert ',
#  ' Mr. John Fredrik Alexander ',
#  ' Mr. Nikola ',
#  ' Jonkheer. John George ',
#  ' Mr. John ',
#  ' Mr. Len ',
#  ' Mr. Thomas Joseph ',
#  ' Mr. Amin ',
#  ' Mr. Albert ',
#  ' Miss. Sara Rebecca ',
#  ' Mr. Maurice ',
#  ' Mr. Chang ',
#  ' Mr. Pierre ',
#  ' Miss. Augusta ',
#  ' Mr. Peter L ',
#  ' Mr. Anthony ',
#  ' Mr. Douglas Bullen ',
#  ' Mr. Marin ',
#  ' Rev. John ',
#  ' Mr. Johan ',
#  ' Mr. Peter Denis  ',
#  ' Mr. Raihed ',
#  ' Mr. Claus Peter ',
#  ' Mr. John William ',
#  ' Miss. Asuncion ',
#  ' Mr. Washington Augustus II ',
#  ' Mr. Philemon ',
#  ' Mr. Cerin ',
#  ' Mr. Frans Olof ',
#  ' Mr. Victor ',
#  ' Mr. Kristo ',
#  ' Mr. Johann ',
#  ' Miss. Gerda Ulrika ',
#  ' Mr. Frederick James ',
#  ' Mr. Henry Jr ',
#  ' Rev. Juozas ',
#  ' Mr. Karl Howell ',
#  ' Mr. Patrick ']

# %%
split("Miss.", names[1])
# Out:
# [' ', ' Laina ']

# %%
string = ("Mr.","Miss.")

# %%
cust[["Title","Name"]]=cust.FullName.str.split(".", expand= True)

# %%
cust.head()
# Out:
#               Name             FullName  Score  Title
# 0     Owen Harris      Mr. Owen Harris       1     Mr
# 1           Laina          Miss. Laina       0   Miss
# 2   William Henry    Mr. William Henry       0     Mr
# 3           James            Mr. James       0     Mr
# 4       Timothy J        Mr. Timothy J       0     Mr
