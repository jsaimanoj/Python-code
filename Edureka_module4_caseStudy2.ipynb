# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Manoj\\Downloads'

# %%
os.chdir('C:\\Users\\Manoj\\Desktop\\Edureka_Python')

# %%
math = pd.read_csv("MathScoreTerm1.csv")
dss = pd.read_csv("DSScoreTerm1.csv")
phys = pd.read_csv("PhysicsScoreTerm1.csv")

# %%
phys.head()
# Out:
#              Name  Score  Age         Ethinicity  Subject Sex  ID
# 0  AI-KYUNG CHUNG   84.0   18     White American  Physics   M   1
# 1     ALAN HARVEY   81.0   19  European American  Physics   M   2
# 2    ALAN REYNAUD   41.0   19  European American  Physics   M   3
# 3  ALBERT CENDANA   78.0   18     White American  Physics   M   4
# 4  ALBERT HOLT JR   78.0   18     White American  Physics   F   5

# %%
math = math.drop("Name", axis = 1)
dss = dss.drop("Name", axis = 1)
phys = phys.drop("Name", axis = 1)

math = math.drop("Ethinicity", axis = 1)
dss = dss.drop("Ethinicity", axis = 1)
phys = phys.drop("Ethinicity", axis = 1)

math.head()
# Out:
#    Score  Age Subject Sex  ID
# 0   88.0   18   Maths   M   1
# 1   85.0   19   Maths   M   2
# 2   45.0   19   Maths   M   3
# 3   82.0   18   Maths   M   4
# 4   82.0   18   Maths   F   5

# %%
math.shape
# Out:
# (599, 5)

# %%
print(len(math[math['Score'].isna()]))
print(len(dss[dss['Score'].isna()]))
print(len(phys[phys['Score'].isna()]))
# Out:
# 3
# 8
# 6

# %%
x = math.iloc[:].values
y = dss.iloc[:].values
z = phys.iloc[:].values

# %%
math[math['Score'].isna()]
math.isnull().sum()
# Out:
# Score      0
# Age        0
# Subject    0
# Sex        0
# ID         0
# dtype: int64

# %%
math['Score'] = math['Score'].fillna('0')
dss['Score'] = dss['Score'].fillna('0')

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer( strategy = 'mean')
z[:,0:1] = np.round(imputer.fit_transform(z[:,0:1]),2)
z[:,0]
# Out:
# array([84.0, 81.0, 41.0, 78.0, 78.0, 91.0, 91.0, 61.0, 84.0, 84.0, 49.0,
#        49.0, 62.0, 84.0, 84.0, 78.0, 70.6, 91.0, 87.0, 62.0, 78.0, 62.0,
#        71.0, 61.0, 87.0, 87.0, 49.0, 87.0, 84.0, 81.0, 71.0, 62.0, 41.0,
#        94.0, 49.0, 61.0, 49.0, 71.0, 41.0, 62.0, 71.0, 91.0, 61.0, 81.0,
#        78.0, 61.0, 81.0, 78.0, 61.0, 62.0, 78.0, 84.0, 41.0, 91.0, 84.0,
#        87.0, 49.0, 71.0, 71.0, 91.0, 84.0, 49.0, 78.0, 78.0, 81.0, 70.6,
#        71.0, 62.0, 41.0, 71.0, 49.0, 61.0, 49.0, 81.0, 78.0, 91.0, 62.0,
#        49.0, 61.0, 81.0, 84.0, 91.0, 49.0, 41.0, 41.0, 81.0, 90.0, 81.0,
#        41.0, 41.0, 70.6, 84.0, 81.0, 87.0, 61.0, 71.0, 84.0, 91.0, 61.0,
#        61.0, 41.0, 49.0, 91.0, 62.0, 78.0, 61.0, 70.6, 81.0, 70.6, 81.0,
#        61.0, 81.0, 84.0, 41.0, 91.0, 84.0, 71.0, 49.0, 78.0, 81.0, 87.0,
#        70.6, 81.0, 41.0, 49.0, 91.0, 41.0, 71.0, 62.0, 71.0, 62.0, 71.0,
#        49.0, 81.0, 81.0, 61.0, 61.0, 87.0, 81.0, 88.0, 78.0, 91.0, 81.0,
# ...

# %%
phys.columns
# Out:
# Index(['Score', 'Age', 'Subject', 'Sex', 'ID'], dtype='object')

# %%
phys1= pd.DataFrame(z)

# %%
phys1.columns= ['Score', 'Age', 'Subject', 'Sex', 'ID']
phys1.head()
# Out:
#   Score Age  Subject Sex ID
# 0    84  18  Physics   M  1
# 1    81  19  Physics   M  2
# 2    41  19  Physics   M  3
# 3    78  18  Physics   M  4
# 4    78  18  Physics   F  5

# %%
maphy = pd.concat([math,phys1], axis = 0)
maphy
# Out:
#     Score Age  Subject Sex   ID
# 0      88  18    Maths   M    1
# 1      85  19    Maths   M    2
# 2      45  19    Maths   M    3
# 3      82  18    Maths   M    4
# 4      82  18    Maths   F    5
# 5      95  20    Maths   M    6
# 6      95  18    Maths   M    7
# 7      65  19    Maths   M    8
# 8      88  18    Maths   M    9
# 9      88  19    Maths   F   10
# 10     53  20    Maths   M   11
# 11     53  20    Maths   M   12
# 12     66  19    Maths   M   13
# 13     88  18    Maths   M   14
# 14     88  21    Maths   F   15
# 15     82  20    Maths   M   16
# 16     31  18    Maths   M   17
# 17     95  18    Maths   M   18
# 18     91  18    Maths   M   19
# 19     66  18    Maths   F   20
# 20     82  18    Maths   M   21
# 21     66  18    Maths   M   22
# 22     75  18    Maths   M   23
# 23     65  19    Maths   M   24
# 24     91  20    Maths   F   25
# 25     91  18    Maths   M   26
# 26     53  20    Maths   M   27
# 27     91  20    Maths   M   28
# ...

# %%
maphyds = pd.concat([maphy,dss], axis = 0)
maphyds
# Out:
#     Score Age        Subject Sex   ID
# 0      88  18          Maths   M    1
# 1      85  19          Maths   M    2
# 2      45  19          Maths   M    3
# 3      82  18          Maths   M    4
# 4      82  18          Maths   F    5
# 5      95  20          Maths   M    6
# 6      95  18          Maths   M    7
# 7      65  19          Maths   M    8
# 8      88  18          Maths   M    9
# 9      88  19          Maths   F   10
# 10     53  20          Maths   M   11
# 11     53  20          Maths   M   12
# 12     66  19          Maths   M   13
# 13     88  18          Maths   M   14
# 14     88  21          Maths   F   15
# 15     82  20          Maths   M   16
# 16     31  18          Maths   M   17
# 17     95  18          Maths   M   18
# 18     91  18          Maths   M   19
# 19     66  18          Maths   F   20
# 20     82  18          Maths   M   21
# 21     66  18          Maths   M   22
# 22     75  18          Maths   M   23
# 23     65  19          Maths   M   24
# ...

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
labelencoder_x = LabelEncoder()

# %%
maphydsarr= maphyds.iloc[:].values
maphydsarr[:,3]= labelencoder_x.fit_transform(maphydsarr[:,3])

# %%
final = pd.DataFrame(maphydsarr)

# %%
final.columns= ['Score', 'Age', 'Subject', 'Sex', 'ID']
final.head()
# Out:
#   Score Age Subject Sex ID
# 0    88  18   Maths   1  1
# 1    85  19   Maths   1  2
# 2    45  19   Maths   1  3
# 3    82  18   Maths   1  4
# 4    82  18   Maths   0  5

# %%
final.to_csv("ScoreFinal.csv")
